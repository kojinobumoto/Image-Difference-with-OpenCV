# %% [markdown]
# ## Compare the differences between two png images
#
# ### Base idea of the image comparison.
# https://www.pyimagesearch.com/2017/06/19/image-difference-with-opencv-and-python/
#
# ### requirement
# + required scikit-image and imutils.
# + scikit-image and imutils shoudl be up-to-date.
#
# + note 1.
# if you use Anaconda, add the "conda-forge" channel and install imutils.
#
# + note 2.
# if you encountered the "rocedure endpoint OPENSSL_sk_nre_reserve could not found" error when installing imutils, check the following page to fix the error.
#     - https://github.com/conda/conda/issues/9003#issuecomment-516499958
#     - i.3. you have to copy the libssl-1_1-x64.dll in Anaconda/DLLS and replaced that in Anaconda/Library/bin
#
# + other requirement
#     - put the base image file(s) into the "img/1.first" folder.
#     - put the comparison file(s) into the "img/2.second" folder.
#     - The image files to be compared in the "1.first" and "2.second" folders must have the same file name.
#     - Do not include UNICODE (double-byte characters or spaces) in file names, including PATH, because cv2.imread() and cv2.imwrite() do not support PATH containing UNICODE.
#
# ### How it works.
# + Finds and compares files with the same name in the "2.second" folder against files in the "1.first" folder.
# + If the file exists in the "1.first" folder but not in the "2.second" folder, an error message will be output.
# + Files that do not exist in the "1.first" folder but exist in the "2.second" folder are not detected.
# + The assumption is that image files of the same dimension are being compared; attempting to compare images of different dimensions will be judged as "there are differences".
# + By default, this program runs in a multi-process manner, launching as many processes as the number of CPU cores on the PC on which it runs.
# + If you want to specify the number of processes to run, specify by changing "num_processors" in the source.

# %% [markdown]
# ## Program body

# %%
#####
# * note
# When you re-run the program after editting module files,
# you'd better to restart the jupyter kernel, especially after editting settings.py.
#####

import multiprocessing as mp
import time
import datetime

from pathlib import Path
from mymodules import settings
from mymodules import workers

import requests

# If there is no folder(s) to save screenshots, create them.
settings.init()

# %% [markdown]
# ### main (calls worker)

# %%
if __name__ == '__main__':
    
    skipUntil = 0 # 1 -> skip 1st line. 200 -> skip first 200 lines.
    stopAt = -1 # 2 -> stop after reading 2 lines. 200 -> stop after reading 200 lines. -1 -> read all lines.
    
    try:
        num_processors = mp.cpu_count()
        #num_processors = 1
        
        p = Path(settings.ORIG_IMAGE_DIRNAME).glob('**/*')
        files = sorted([x for x in p if x.is_file()])  # sort by file name.
        
        index = 0
        arr_orig_image_lists = []
        for orig_image_with_path in files:
            index += 1
            if index < skipUntil:
                continue
            if stopAt > 0 and stopAt == index:
                arr_orig_image_lists.append(orig_image_with_path)
                print(f'image file in writer() : {index} - {orig_image_with_path}')
                break
            print(f'image file in writer() : {index} - {orig_image_with_path}')
            arr_orig_image_lists.append(orig_image_with_path)
        
        time_start = time.time()
        
        str_start_datetime = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
        print(f'Start at {str_start_datetime}')

        #p = mp.Pool(processes = num_processors)
        p = mp.Pool(processes = num_processors, initializer = workers.compimgdiff_init, initargs= [str_start_datetime])
        arr_result = p.map(workers.compare_image_diff, arr_orig_image_lists)
        
        time_end = time.time()
        time_diff =time_end - time_start
        str_end_datetime = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
        print(f'time : {time_diff}')
        #dt_end = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
        
        with open('results-' + str_start_datetime + '.csv', 'a', encoding="utf-8_sig") as result_file:
            for ar in arr_result:
                # ar's shape is [ssim_score, image_filename, messages]
                result_file.write(f'{ar[0]},{ar[1]},"{ar[2]}"\n')
        print("Finished")
        
        # slack_notify(msg = '[Image Difference] finished at {}. It took {} seconds.'.format(str_end_datetime, str(time_diff)))
        
    except Exception as ex:
        print(f'{type(ex).__name__}: {ex}')
        raise
    finally:
        #workers.quit_web_driver()
        pass
# Out:
# image file in writer() : 1 - img\01.first\1.png
# image file in writer() : 2 - img\01.first\10.png
# image file in writer() : 3 - img\01.first\100.png
# image file in writer() : 4 - img\01.first\1000.png
# image file in writer() : 5 - img\01.first\1001.png
# image file in writer() : 6 - img\01.first\1002.png
# image file in writer() : 7 - img\01.first\1003.png
# image file in writer() : 8 - img\01.first\1004.png
# image file in writer() : 9 - img\01.first\1005.png
# image file in writer() : 10 - img\01.first\1006.png
# image file in writer() : 11 - img\01.first\1007.png
# image file in writer() : 12 - img\01.first\1008.png
# image file in writer() : 13 - img\01.first\1009.png
# image file in writer() : 14 - img\01.first\101.png
# image file in writer() : 15 - img\01.first\1010.png
# image file in writer() : 16 - img\01.first\1011.png
# image file in writer() : 17 - img\01.first\1012.png
# image file in writer() : 18 - img\01.first\1013.png
# image file in writer() : 19 - img\01.first\1014.png
# image file in writer() : 20 - img\01.first\1015.png
# image file in writer() : 21 - img\01.first\1016.png
# image file in writer() : 22 - img\01.first\1017.png
# image file in writer() : 23 - img\01.first\1018.png
# image file in writer() : 24 - img\01.first\1019.png
# image file in writer() : 25 - img\01.first\102.png
# image file in writer() : 26 - img\01.first\1020.png
# image file in writer() : 27 - img\01.first\1021.png
# image file in writer() : 28 - img\01.first\1022.png
# image file in writer() : 29 - img\01.first\1023.png
# image file in writer() : 30 - img\01.first\1024.png
# image file in writer() : 31 - img\01.first\1025.png
# image file in writer() : 32 - img\01.first\1026.png
# image file in writer() : 33 - img\01.first\1027.png
# image file in writer() : 34 - img\01.first\1028.png
# image file in writer() : 35 - img\01.first\1029.png
# image file in writer() : 36 - img\01.first\103.png
# image file in writer() : 37 - img\01.first\1030.png
# image file in writer() : 38 - img\01.first\1031.png
# image file in writer() : 39 - img\01.first\1032.png
# image file in writer() : 40 - img\01.first\1033.png
# image file in writer() : 41 - img\01.first\1034.png
# image file in writer() : 42 - img\01.first\1035.png
# image file in writer() : 43 - img\01.first\1036.png
# image file in writer() : 44 - img\01.first\1037.png
# image file in writer() : 45 - img\01.first\1038.png
# image file in writer() : 46 - img\01.first\1039.png
# image file in writer() : 47 - img\01.first\104.png
# image file in writer() : 48 - img\01.first\1040.png
# image file in writer() : 49 - img\01.first\1041.png
# image file in writer() : 50 - img\01.first\1042.png
# image file in writer() : 51 - img\01.first\1043.png
# image file in writer() : 52 - img\01.first\1044.png
# image file in writer() : 53 - img\01.first\1045.png
# image file in writer() : 54 - img\01.first\1046.png
# image file in writer() : 55 - img\01.first\1047.png
# image file in writer() : 56 - img\01.first\1048.png
# image file in writer() : 57 - img\01.first\1049.png
# image file in writer() : 58 - img\01.first\105.png
# image file in writer() : 59 - img\01.first\1050.png
# image file in writer() : 60 - img\01.first\1051.png
# image file in writer() : 61 - img\01.first\1052.png
# image file in writer() : 62 - img\01.first\1053.png
# image file in writer() : 63 - img\01.first\1054.png
# image file in writer() : 64 - img\01.first\1055.png
# image file in writer() : 65 - img\01.first\1056.png
# image file in writer() : 66 - img\01.first\1057.png
# image file in writer() : 67 - img\01.first\1058.png
# image file in writer() : 68 - img\01.first\1059.png
# image file in writer() : 69 - img\01.first\1060.png
# image file in writer() : 70 - img\01.first\1061.png
# image file in writer() : 71 - img\01.first\1062.png
# image file in writer() : 72 - img\01.first\1063.png
# image file in writer() : 73 - img\01.first\1064.png
# image file in writer() : 74 - img\01.first\1065.png
# image file in writer() : 75 - img\01.first\1066.png
# image file in writer() : 76 - img\01.first\1067.png
# image file in writer() : 77 - img\01.first\107.png
# image file in writer() : 78 - img\01.first\1071.png
# image file in writer() : 79 - img\01.first\1073.png
# image file in writer() : 80 - img\01.first\1075.png
# image file in writer() : 81 - img\01.first\1076.png
# image file in writer() : 82 - img\01.first\1077.png
# image file in writer() : 83 - img\01.first\1078.png
# image file in writer() : 84 - img\01.first\1079.png
# image file in writer() : 85 - img\01.first\108.png
# image file in writer() : 86 - img\01.first\1082.png
# image file in writer() : 87 - img\01.first\1084.png
# image file in writer() : 88 - img\01.first\1086.png
# image file in writer() : 89 - img\01.first\1088.png
# image file in writer() : 90 - img\01.first\1089.png
# image file in writer() : 91 - img\01.first\109.png
# image file in writer() : 92 - img\01.first\1090.png
# image file in writer() : 93 - img\01.first\1091.png
# image file in writer() : 94 - img\01.first\1092.png
# image file in writer() : 95 - img\01.first\1093.png
# image file in writer() : 96 - img\01.first\1094.png
# image file in writer() : 97 - img\01.first\1095.png
# image file in writer() : 98 - img\01.first\1096.png
# image file in writer() : 99 - img\01.first\1097.png
# image file in writer() : 100 - img\01.first\1098.png
# image file in writer() : 101 - img\01.first\1099.png
# image file in writer() : 102 - img\01.first\11.png
# image file in writer() : 103 - img\01.first\110.png
# image file in writer() : 104 - img\01.first\1100.png
# image file in writer() : 105 - img\01.first\1101.png
# image file in writer() : 106 - img\01.first\1102.png
# image file in writer() : 107 - img\01.first\1103.png
# image file in writer() : 108 - img\01.first\1104.png
# image file in writer() : 109 - img\01.first\1105.png
# image file in writer() : 110 - img\01.first\1106.png
# image file in writer() : 111 - img\01.first\1107.png
# image file in writer() : 112 - img\01.first\1108.png
# image file in writer() : 113 - img\01.first\1109.png
# image file in writer() : 114 - img\01.first\111.png
# image file in writer() : 115 - img\01.first\1110.png
# image file in writer() : 116 - img\01.first\1111.png
# image file in writer() : 117 - img\01.first\1112.png
# image file in writer() : 118 - img\01.first\1113.png
# image file in writer() : 119 - img\01.first\1114.png
# image file in writer() : 120 - img\01.first\1115.png
# image file in writer() : 121 - img\01.first\1116.png
# image file in writer() : 122 - img\01.first\1117.png
# image file in writer() : 123 - img\01.first\1118.png
# image file in writer() : 124 - img\01.first\1119.png
# image file in writer() : 125 - img\01.first\112.png
# image file in writer() : 126 - img\01.first\1120.png
# image file in writer() : 127 - img\01.first\1121.png
# image file in writer() : 128 - img\01.first\1122.png
# image file in writer() : 129 - img\01.first\1123.png
# image file in writer() : 130 - img\01.first\1124.png
# image file in writer() : 131 - img\01.first\1125.png
# image file in writer() : 132 - img\01.first\1126.png
# image file in writer() : 133 - img\01.first\1127.png
# image file in writer() : 134 - img\01.first\1128.png
# image file in writer() : 135 - img\01.first\1129.png
# image file in writer() : 136 - img\01.first\113.png
# image file in writer() : 137 - img\01.first\1130.png
# image file in writer() : 138 - img\01.first\1131.png
# image file in writer() : 139 - img\01.first\1132.png
# image file in writer() : 140 - img\01.first\1133.png
# image file in writer() : 141 - img\01.first\1134.png
# image file in writer() : 142 - img\01.first\1135.png
# image file in writer() : 143 - img\01.first\1136.png
# image file in writer() : 144 - img\01.first\1137.png
# image file in writer() : 145 - img\01.first\1138.png
# image file in writer() : 146 - img\01.first\1139.png
# image file in writer() : 147 - img\01.first\114.png
# image file in writer() : 148 - img\01.first\1140.png
# image file in writer() : 149 - img\01.first\1141.png
# image file in writer() : 150 - img\01.first\1142.png
# image file in writer() : 151 - img\01.first\1143.png
# image file in writer() : 152 - img\01.first\1144.png
# image file in writer() : 153 - img\01.first\1145.png
# image file in writer() : 154 - img\01.first\1146.png
# image file in writer() : 155 - img\01.first\1147.png
# image file in writer() : 156 - img\01.first\1148.png
# image file in writer() : 157 - img\01.first\1149.png
# image file in writer() : 158 - img\01.first\115.png
# image file in writer() : 159 - img\01.first\1150.png
# image file in writer() : 160 - img\01.first\1151.png
# image file in writer() : 161 - img\01.first\1152.png
# image file in writer() : 162 - img\01.first\1153.png
# image file in writer() : 163 - img\01.first\1154.png
# image file in writer() : 164 - img\01.first\1155.png
# image file in writer() : 165 - img\01.first\1156.png
# image file in writer() : 166 - img\01.first\1157.png
# image file in writer() : 167 - img\01.first\1158.png
# image file in writer() : 168 - img\01.first\1159.png
# image file in writer() : 169 - img\01.first\116.png
# image file in writer() : 170 - img\01.first\1160.png
# image file in writer() : 171 - img\01.first\1161.png
# image file in writer() : 172 - img\01.first\1162.png
# image file in writer() : 173 - img\01.first\1163.png
# image file in writer() : 174 - img\01.first\1164.png
# image file in writer() : 175 - img\01.first\1165.png
# image file in writer() : 176 - img\01.first\1166.png
# image file in writer() : 177 - img\01.first\1167.png
# image file in writer() : 178 - img\01.first\1168.png
# image file in writer() : 179 - img\01.first\1169.png
# image file in writer() : 180 - img\01.first\117.png
# image file in writer() : 181 - img\01.first\1170.png
# image file in writer() : 182 - img\01.first\1171.png
# image file in writer() : 183 - img\01.first\1172.png
# image file in writer() : 184 - img\01.first\1173.png
# image file in writer() : 185 - img\01.first\1174.png
# image file in writer() : 186 - img\01.first\1175.png
# image file in writer() : 187 - img\01.first\1176.png
# image file in writer() : 188 - img\01.first\1177.png
# image file in writer() : 189 - img\01.first\1178.png
# image file in writer() : 190 - img\01.first\1179.png
# image file in writer() : 191 - img\01.first\118.png
# image file in writer() : 192 - img\01.first\1180.png
# image file in writer() : 193 - img\01.first\1181.png
# image file in writer() : 194 - img\01.first\1182.png
# image file in writer() : 195 - img\01.first\1183.png
# image file in writer() : 196 - img\01.first\1184.png
# image file in writer() : 197 - img\01.first\1185.png
# image file in writer() : 198 - img\01.first\1186.png
# image file in writer() : 199 - img\01.first\1187.png
# image file in writer() : 200 - img\01.first\1188.png
# image file in writer() : 201 - img\01.first\1189.png
# image file in writer() : 202 - img\01.first\119.png
# image file in writer() : 203 - img\01.first\1190.png
# image file in writer() : 204 - img\01.first\1191.png
# image file in writer() : 205 - img\01.first\1192.png
# image file in writer() : 206 - img\01.first\1193.png
# image file in writer() : 207 - img\01.first\1194.png
# image file in writer() : 208 - img\01.first\1196.png
# image file in writer() : 209 - img\01.first\1197.png
# image file in writer() : 210 - img\01.first\1198.png
# image file in writer() : 211 - img\01.first\1199.png
# image file in writer() : 212 - img\01.first\12.png
# image file in writer() : 213 - img\01.first\120.png
# image file in writer() : 214 - img\01.first\1200.png
# image file in writer() : 215 - img\01.first\1201.png
# image file in writer() : 216 - img\01.first\1202.png
# image file in writer() : 217 - img\01.first\1203.png
# image file in writer() : 218 - img\01.first\1204.png
# image file in writer() : 219 - img\01.first\1205.png
# image file in writer() : 220 - img\01.first\1206.png
# image file in writer() : 221 - img\01.first\1207.png
# image file in writer() : 222 - img\01.first\1208.png
# image file in writer() : 223 - img\01.first\1209.png
# image file in writer() : 224 - img\01.first\121.png
# image file in writer() : 225 - img\01.first\1210.png
# image file in writer() : 226 - img\01.first\1211.png
# image file in writer() : 227 - img\01.first\1212.png
# image file in writer() : 228 - img\01.first\1213.png
# image file in writer() : 229 - img\01.first\1214.png
# image file in writer() : 230 - img\01.first\1215.png
# image file in writer() : 231 - img\01.first\1216.png
# image file in writer() : 232 - img\01.first\1217.png
# image file in writer() : 233 - img\01.first\1218.png
# image file in writer() : 234 - img\01.first\1219.png
# image file in writer() : 235 - img\01.first\122.png
# image file in writer() : 236 - img\01.first\1220.png
# image file in writer() : 237 - img\01.first\1221.png
# image file in writer() : 238 - img\01.first\1222.png
# image file in writer() : 239 - img\01.first\1223.png
# image file in writer() : 240 - img\01.first\1224.png
# image file in writer() : 241 - img\01.first\1225.png
# image file in writer() : 242 - img\01.first\1226.png
# image file in writer() : 243 - img\01.first\1227.png
# image file in writer() : 244 - img\01.first\1228.png
# image file in writer() : 245 - img\01.first\1229.png
# image file in writer() : 246 - img\01.first\123.png
# image file in writer() : 247 - img\01.first\1230.png
# image file in writer() : 248 - img\01.first\1231.png
# image file in writer() : 249 - img\01.first\1232.png
# image file in writer() : 250 - img\01.first\1233.png
# image file in writer() : 251 - img\01.first\1234.png
# image file in writer() : 252 - img\01.first\1235.png
# image file in writer() : 253 - img\01.first\1236.png
# image file in writer() : 254 - img\01.first\1237.png
# image file in writer() : 255 - img\01.first\1238.png
# image file in writer() : 256 - img\01.first\1239.png
# image file in writer() : 257 - img\01.first\124.png
# image file in writer() : 258 - img\01.first\1240.png
# image file in writer() : 259 - img\01.first\1241.png
# image file in writer() : 260 - img\01.first\1242.png
# image file in writer() : 261 - img\01.first\1243.png
# image file in writer() : 262 - img\01.first\1244.png
# image file in writer() : 263 - img\01.first\1245.png
# image file in writer() : 264 - img\01.first\1246.png
# image file in writer() : 265 - img\01.first\1247.png
# image file in writer() : 266 - img\01.first\1248.png
# image file in writer() : 267 - img\01.first\1249.png
# image file in writer() : 268 - img\01.first\125.png
# image file in writer() : 269 - img\01.first\1250.png
# image file in writer() : 270 - img\01.first\1251.png
# image file in writer() : 271 - img\01.first\1252.png
# image file in writer() : 272 - img\01.first\1253.png
# image file in writer() : 273 - img\01.first\1254.png
# image file in writer() : 274 - img\01.first\1255.png
# image file in writer() : 275 - img\01.first\1256.png
# image file in writer() : 276 - img\01.first\1257.png
# image file in writer() : 277 - img\01.first\1258.png
# image file in writer() : 278 - img\01.first\1259.png
# image file in writer() : 279 - img\01.first\126.png
# image file in writer() : 280 - img\01.first\1260.png
# image file in writer() : 281 - img\01.first\1261.png
# image file in writer() : 282 - img\01.first\1262.png
# image file in writer() : 283 - img\01.first\1263.png
# image file in writer() : 284 - img\01.first\1264.png
# image file in writer() : 285 - img\01.first\1265.png
# image file in writer() : 286 - img\01.first\1266.png
# image file in writer() : 287 - img\01.first\1267.png
# image file in writer() : 288 - img\01.first\1268.png
# image file in writer() : 289 - img\01.first\1269.png
# image file in writer() : 290 - img\01.first\127.png
# image file in writer() : 291 - img\01.first\1270.png
# image file in writer() : 292 - img\01.first\1271.png
# image file in writer() : 293 - img\01.first\1272.png
# image file in writer() : 294 - img\01.first\1274.png
# image file in writer() : 295 - img\01.first\1275.png
# image file in writer() : 296 - img\01.first\1276.png
# image file in writer() : 297 - img\01.first\1277.png
# image file in writer() : 298 - img\01.first\1278.png
# image file in writer() : 299 - img\01.first\1279.png
# image file in writer() : 300 - img\01.first\128.png
# image file in writer() : 301 - img\01.first\1280.png
# image file in writer() : 302 - img\01.first\1281.png
# image file in writer() : 303 - img\01.first\1283.png
# image file in writer() : 304 - img\01.first\1284.png
# image file in writer() : 305 - img\01.first\1285.png
# image file in writer() : 306 - img\01.first\1286.png
# image file in writer() : 307 - img\01.first\1287.png
# image file in writer() : 308 - img\01.first\1288.png
# image file in writer() : 309 - img\01.first\1289.png
# image file in writer() : 310 - img\01.first\129.png
# image file in writer() : 311 - img\01.first\1290.png
# image file in writer() : 312 - img\01.first\1291.png
# image file in writer() : 313 - img\01.first\1292.png
# image file in writer() : 314 - img\01.first\1293.png
# image file in writer() : 315 - img\01.first\1294.png
# image file in writer() : 316 - img\01.first\1295.png
# image file in writer() : 317 - img\01.first\1296.png
# image file in writer() : 318 - img\01.first\1297.png
# image file in writer() : 319 - img\01.first\1298.png
# image file in writer() : 320 - img\01.first\1299.png
# image file in writer() : 321 - img\01.first\13.png
# image file in writer() : 322 - img\01.first\130.png
# image file in writer() : 323 - img\01.first\1300.png
# image file in writer() : 324 - img\01.first\1301.png
# image file in writer() : 325 - img\01.first\1302.png
# image file in writer() : 326 - img\01.first\1303.png
# image file in writer() : 327 - img\01.first\1304.png
# image file in writer() : 328 - img\01.first\1305.png
# image file in writer() : 329 - img\01.first\1306.png
# image file in writer() : 330 - img\01.first\1307.png
# image file in writer() : 331 - img\01.first\1309.png
# image file in writer() : 332 - img\01.first\131.png
# image file in writer() : 333 - img\01.first\1310.png
# image file in writer() : 334 - img\01.first\1311.png
# image file in writer() : 335 - img\01.first\1312.png
# image file in writer() : 336 - img\01.first\1314.png
# image file in writer() : 337 - img\01.first\1315.png
# image file in writer() : 338 - img\01.first\1316.png
# image file in writer() : 339 - img\01.first\1317.png
# image file in writer() : 340 - img\01.first\1318.png
# image file in writer() : 341 - img\01.first\1319.png
# image file in writer() : 342 - img\01.first\132.png
# image file in writer() : 343 - img\01.first\1320.png
# image file in writer() : 344 - img\01.first\1321.png
# image file in writer() : 345 - img\01.first\1322.png
# image file in writer() : 346 - img\01.first\1323.png
# image file in writer() : 347 - img\01.first\1324.png
# image file in writer() : 348 - img\01.first\1325.png
# image file in writer() : 349 - img\01.first\1326.png
# image file in writer() : 350 - img\01.first\1328.png
# image file in writer() : 351 - img\01.first\133.png
# image file in writer() : 352 - img\01.first\1331.png
# image file in writer() : 353 - img\01.first\1332.png
# image file in writer() : 354 - img\01.first\134.png
# image file in writer() : 355 - img\01.first\1344.png
# image file in writer() : 356 - img\01.first\135.png
# image file in writer() : 357 - img\01.first\136.png
# image file in writer() : 358 - img\01.first\137.png
# image file in writer() : 359 - img\01.first\138.png
# image file in writer() : 360 - img\01.first\1381.png
# image file in writer() : 361 - img\01.first\1383.png
# image file in writer() : 362 - img\01.first\1384.png
# image file in writer() : 363 - img\01.first\1385.png
# image file in writer() : 364 - img\01.first\1387.png
# image file in writer() : 365 - img\01.first\139.png
# image file in writer() : 366 - img\01.first\1393.png
# image file in writer() : 367 - img\01.first\1395.png
# image file in writer() : 368 - img\01.first\1396.png
# image file in writer() : 369 - img\01.first\1397.png
# image file in writer() : 370 - img\01.first\1398.png
# image file in writer() : 371 - img\01.first\1399.png
# image file in writer() : 372 - img\01.first\14.png
# image file in writer() : 373 - img\01.first\140.png
# image file in writer() : 374 - img\01.first\1400.png
# image file in writer() : 375 - img\01.first\1403.png
# image file in writer() : 376 - img\01.first\1404.png
# image file in writer() : 377 - img\01.first\1405.png
# image file in writer() : 378 - img\01.first\1406.png
# image file in writer() : 379 - img\01.first\1407.png
# image file in writer() : 380 - img\01.first\1408.png
# image file in writer() : 381 - img\01.first\1409.png
# image file in writer() : 382 - img\01.first\141.png
# image file in writer() : 383 - img\01.first\1410.png
# image file in writer() : 384 - img\01.first\1411.png
# image file in writer() : 385 - img\01.first\1412.png
# image file in writer() : 386 - img\01.first\1413.png
# image file in writer() : 387 - img\01.first\1414.png
# image file in writer() : 388 - img\01.first\1415.png
# image file in writer() : 389 - img\01.first\1416.png
# image file in writer() : 390 - img\01.first\1417.png
# image file in writer() : 391 - img\01.first\1418.png
# image file in writer() : 392 - img\01.first\142.png
# image file in writer() : 393 - img\01.first\1420.png
# image file in writer() : 394 - img\01.first\1421.png
# image file in writer() : 395 - img\01.first\1422.png
# image file in writer() : 396 - img\01.first\1423.png
# image file in writer() : 397 - img\01.first\1424.png
# image file in writer() : 398 - img\01.first\1425.png
# image file in writer() : 399 - img\01.first\1426.png
# image file in writer() : 400 - img\01.first\1427.png
# image file in writer() : 401 - img\01.first\1428.png
# image file in writer() : 402 - img\01.first\1429.png
# image file in writer() : 403 - img\01.first\143.png
# image file in writer() : 404 - img\01.first\1430.png
# image file in writer() : 405 - img\01.first\1431.png
# image file in writer() : 406 - img\01.first\1432.png
# image file in writer() : 407 - img\01.first\1433.png
# image file in writer() : 408 - img\01.first\1434.png
# image file in writer() : 409 - img\01.first\1435.png
# image file in writer() : 410 - img\01.first\1436.png
# image file in writer() : 411 - img\01.first\1437.png
# image file in writer() : 412 - img\01.first\1438.png
# image file in writer() : 413 - img\01.first\1439.png
# image file in writer() : 414 - img\01.first\144.png
# image file in writer() : 415 - img\01.first\1440.png
# image file in writer() : 416 - img\01.first\1441.png
# image file in writer() : 417 - img\01.first\1442.png
# image file in writer() : 418 - img\01.first\1443.png
# image file in writer() : 419 - img\01.first\1444.png
# image file in writer() : 420 - img\01.first\1445.png
# image file in writer() : 421 - img\01.first\1446.png
# image file in writer() : 422 - img\01.first\1447.png
# image file in writer() : 423 - img\01.first\1448.png
# image file in writer() : 424 - img\01.first\1449.png
# image file in writer() : 425 - img\01.first\145.png
# image file in writer() : 426 - img\01.first\1450.png
# image file in writer() : 427 - img\01.first\1451.png
# image file in writer() : 428 - img\01.first\1452.png
# image file in writer() : 429 - img\01.first\1453.png
# image file in writer() : 430 - img\01.first\1454.png
# image file in writer() : 431 - img\01.first\1455.png
# image file in writer() : 432 - img\01.first\1456.png
# image file in writer() : 433 - img\01.first\1457.png
# image file in writer() : 434 - img\01.first\1458.png
# image file in writer() : 435 - img\01.first\1459.png
# image file in writer() : 436 - img\01.first\146.png
# image file in writer() : 437 - img\01.first\1460.png
# image file in writer() : 438 - img\01.first\1461.png
# image file in writer() : 439 - img\01.first\1462.png
# image file in writer() : 440 - img\01.first\1463.png
# image file in writer() : 441 - img\01.first\1464.png
# image file in writer() : 442 - img\01.first\1465.png
# image file in writer() : 443 - img\01.first\1466.png
# image file in writer() : 444 - img\01.first\1467.png
# image file in writer() : 445 - img\01.first\1468.png
# image file in writer() : 446 - img\01.first\1469.png
# image file in writer() : 447 - img\01.first\147.png
# image file in writer() : 448 - img\01.first\1470.png
# image file in writer() : 449 - img\01.first\1471.png
# image file in writer() : 450 - img\01.first\1472.png
# image file in writer() : 451 - img\01.first\1473.png
# image file in writer() : 452 - img\01.first\1474.png
# image file in writer() : 453 - img\01.first\1475.png
# image file in writer() : 454 - img\01.first\1476.png
# image file in writer() : 455 - img\01.first\1477.png
# image file in writer() : 456 - img\01.first\1478.png
# image file in writer() : 457 - img\01.first\1479.png
# image file in writer() : 458 - img\01.first\148.png
# image file in writer() : 459 - img\01.first\1480.png
# image file in writer() : 460 - img\01.first\1481.png
# image file in writer() : 461 - img\01.first\1482.png
# image file in writer() : 462 - img\01.first\1483.png
# image file in writer() : 463 - img\01.first\1484.png
# image file in writer() : 464 - img\01.first\1485.png
# image file in writer() : 465 - img\01.first\1486.png
# image file in writer() : 466 - img\01.first\1487.png
# image file in writer() : 467 - img\01.first\1488.png
# image file in writer() : 468 - img\01.first\1489.png
# image file in writer() : 469 - img\01.first\149.png
# image file in writer() : 470 - img\01.first\1490.png
# image file in writer() : 471 - img\01.first\1492.png
# image file in writer() : 472 - img\01.first\1493.png
# image file in writer() : 473 - img\01.first\1494.png
# image file in writer() : 474 - img\01.first\1495.png
# image file in writer() : 475 - img\01.first\1496.png
# image file in writer() : 476 - img\01.first\1497.png
# image file in writer() : 477 - img\01.first\1498.png
# image file in writer() : 478 - img\01.first\1499.png
# image file in writer() : 479 - img\01.first\15.png
# image file in writer() : 480 - img\01.first\150.png
# image file in writer() : 481 - img\01.first\1500.png
# image file in writer() : 482 - img\01.first\1502.png
# image file in writer() : 483 - img\01.first\1503.png
# image file in writer() : 484 - img\01.first\1504.png
# image file in writer() : 485 - img\01.first\1505.png
# image file in writer() : 486 - img\01.first\1507.png
# image file in writer() : 487 - img\01.first\151.png
# image file in writer() : 488 - img\01.first\1510.png
# image file in writer() : 489 - img\01.first\1511.png
# image file in writer() : 490 - img\01.first\1512.png
# image file in writer() : 491 - img\01.first\1513.png
# image file in writer() : 492 - img\01.first\1515.png
# image file in writer() : 493 - img\01.first\1516.png
# image file in writer() : 494 - img\01.first\1517.png
# image file in writer() : 495 - img\01.first\1519.png
# image file in writer() : 496 - img\01.first\152.png
# image file in writer() : 497 - img\01.first\1520.png
# image file in writer() : 498 - img\01.first\1521.png
# image file in writer() : 499 - img\01.first\1522.png
# image file in writer() : 500 - img\01.first\1523.png
# image file in writer() : 501 - img\01.first\1524.png
# image file in writer() : 502 - img\01.first\1525.png
# image file in writer() : 503 - img\01.first\1526.png
# image file in writer() : 504 - img\01.first\1527.png
# image file in writer() : 505 - img\01.first\1528.png
# image file in writer() : 506 - img\01.first\1529.png
# image file in writer() : 507 - img\01.first\153.png
# image file in writer() : 508 - img\01.first\1530.png
# image file in writer() : 509 - img\01.first\1531.png
# image file in writer() : 510 - img\01.first\1532.png
# image file in writer() : 511 - img\01.first\1533.png
# image file in writer() : 512 - img\01.first\1534.png
# image file in writer() : 513 - img\01.first\1535.png
# image file in writer() : 514 - img\01.first\1536.png
# image file in writer() : 515 - img\01.first\1537.png
# image file in writer() : 516 - img\01.first\1538.png
# image file in writer() : 517 - img\01.first\1539.png
# image file in writer() : 518 - img\01.first\154.png
# image file in writer() : 519 - img\01.first\1540.png
# image file in writer() : 520 - img\01.first\1541.png
# image file in writer() : 521 - img\01.first\1542.png
# image file in writer() : 522 - img\01.first\1543.png
# image file in writer() : 523 - img\01.first\1544.png
# image file in writer() : 524 - img\01.first\1545.png
# image file in writer() : 525 - img\01.first\1546.png
# image file in writer() : 526 - img\01.first\155.png
# image file in writer() : 527 - img\01.first\1552.png
# image file in writer() : 528 - img\01.first\1553.png
# image file in writer() : 529 - img\01.first\1554.png
# image file in writer() : 530 - img\01.first\1555.png
# image file in writer() : 531 - img\01.first\1556.png
# image file in writer() : 532 - img\01.first\1557.png
# image file in writer() : 533 - img\01.first\1558.png
# image file in writer() : 534 - img\01.first\156.png
# image file in writer() : 535 - img\01.first\1560.png
# image file in writer() : 536 - img\01.first\1562.png
# image file in writer() : 537 - img\01.first\1563.png
# image file in writer() : 538 - img\01.first\1564.png
# image file in writer() : 539 - img\01.first\1565.png
# image file in writer() : 540 - img\01.first\1566.png
# image file in writer() : 541 - img\01.first\1567.png
# image file in writer() : 542 - img\01.first\1568.png
# image file in writer() : 543 - img\01.first\1569.png
# image file in writer() : 544 - img\01.first\157.png
# image file in writer() : 545 - img\01.first\1570.png
# image file in writer() : 546 - img\01.first\1571.png
# image file in writer() : 547 - img\01.first\1572.png
# image file in writer() : 548 - img\01.first\1573.png
# image file in writer() : 549 - img\01.first\1574.png
# image file in writer() : 550 - img\01.first\1575.png
# image file in writer() : 551 - img\01.first\1576.png
# image file in writer() : 552 - img\01.first\1578.png
# image file in writer() : 553 - img\01.first\1579.png
# image file in writer() : 554 - img\01.first\158.png
# image file in writer() : 555 - img\01.first\1580.png
# image file in writer() : 556 - img\01.first\1581.png
# image file in writer() : 557 - img\01.first\1582.png
# image file in writer() : 558 - img\01.first\1583.png
# image file in writer() : 559 - img\01.first\1584.png
# image file in writer() : 560 - img\01.first\1587.png
# image file in writer() : 561 - img\01.first\1588.png
# image file in writer() : 562 - img\01.first\1589.png
# image file in writer() : 563 - img\01.first\159.png
# image file in writer() : 564 - img\01.first\1590.png
# image file in writer() : 565 - img\01.first\1591.png
# image file in writer() : 566 - img\01.first\1592.png
# image file in writer() : 567 - img\01.first\1593.png
# image file in writer() : 568 - img\01.first\1594.png
# image file in writer() : 569 - img\01.first\1595.png
# image file in writer() : 570 - img\01.first\1596.png
# image file in writer() : 571 - img\01.first\1597.png
# image file in writer() : 572 - img\01.first\1598.png
# image file in writer() : 573 - img\01.first\1599.png
# image file in writer() : 574 - img\01.first\16.png
# image file in writer() : 575 - img\01.first\160.png
# image file in writer() : 576 - img\01.first\1600.png
# image file in writer() : 577 - img\01.first\1604.png
# image file in writer() : 578 - img\01.first\1605.png
# image file in writer() : 579 - img\01.first\1606.png
# image file in writer() : 580 - img\01.first\1607.png
# image file in writer() : 581 - img\01.first\1608.png
# image file in writer() : 582 - img\01.first\1609.png
# image file in writer() : 583 - img\01.first\161.png
# image file in writer() : 584 - img\01.first\1610.png
# image file in writer() : 585 - img\01.first\1613.png
# image file in writer() : 586 - img\01.first\1614.png
# image file in writer() : 587 - img\01.first\1615.png
# image file in writer() : 588 - img\01.first\1616.png
# image file in writer() : 589 - img\01.first\1617.png
# image file in writer() : 590 - img\01.first\1618.png
# image file in writer() : 591 - img\01.first\1619.png
# image file in writer() : 592 - img\01.first\162.png
# image file in writer() : 593 - img\01.first\1621.png
# image file in writer() : 594 - img\01.first\1623.png
# image file in writer() : 595 - img\01.first\1624.png
# image file in writer() : 596 - img\01.first\1625.png
# image file in writer() : 597 - img\01.first\1627.png
# image file in writer() : 598 - img\01.first\1629.png
# image file in writer() : 599 - img\01.first\163.png
# image file in writer() : 600 - img\01.first\1631.png
# image file in writer() : 601 - img\01.first\1633.png
# image file in writer() : 602 - img\01.first\1634.png
# image file in writer() : 603 - img\01.first\1635.png
# image file in writer() : 604 - img\01.first\1637.png
# image file in writer() : 605 - img\01.first\1638.png
# image file in writer() : 606 - img\01.first\1639.png
# image file in writer() : 607 - img\01.first\164.png
# image file in writer() : 608 - img\01.first\1640.png
# image file in writer() : 609 - img\01.first\1641.png
# image file in writer() : 610 - img\01.first\1642.png
# image file in writer() : 611 - img\01.first\1643.png
# image file in writer() : 612 - img\01.first\1644.png
# image file in writer() : 613 - img\01.first\1645.png
# image file in writer() : 614 - img\01.first\1646.png
# image file in writer() : 615 - img\01.first\1648.png
# image file in writer() : 616 - img\01.first\165.png
# image file in writer() : 617 - img\01.first\1650.png
# image file in writer() : 618 - img\01.first\1651.png
# image file in writer() : 619 - img\01.first\1652.png
# image file in writer() : 620 - img\01.first\1653.png
# image file in writer() : 621 - img\01.first\1654.png
# image file in writer() : 622 - img\01.first\1655.png
# image file in writer() : 623 - img\01.first\1656.png
# image file in writer() : 624 - img\01.first\1657.png
# image file in writer() : 625 - img\01.first\1658.png
# image file in writer() : 626 - img\01.first\1659.png
# image file in writer() : 627 - img\01.first\166.png
# image file in writer() : 628 - img\01.first\1660.png
# image file in writer() : 629 - img\01.first\1661.png
# image file in writer() : 630 - img\01.first\1662.png
# image file in writer() : 631 - img\01.first\1663.png
# image file in writer() : 632 - img\01.first\1665.png
# image file in writer() : 633 - img\01.first\1666.png
# image file in writer() : 634 - img\01.first\1667.png
# image file in writer() : 635 - img\01.first\1668.png
# image file in writer() : 636 - img\01.first\1669.png
# image file in writer() : 637 - img\01.first\167.png
# image file in writer() : 638 - img\01.first\1671.png
# image file in writer() : 639 - img\01.first\1673.png
# image file in writer() : 640 - img\01.first\1674.png
# image file in writer() : 641 - img\01.first\1675.png
# image file in writer() : 642 - img\01.first\1676.png
# image file in writer() : 643 - img\01.first\1677.png
# image file in writer() : 644 - img\01.first\1678.png
# image file in writer() : 645 - img\01.first\168.png
# image file in writer() : 646 - img\01.first\1680.png
# image file in writer() : 647 - img\01.first\1681.png
# image file in writer() : 648 - img\01.first\1682.png
# image file in writer() : 649 - img\01.first\1683.png
# image file in writer() : 650 - img\01.first\1684.png
# image file in writer() : 651 - img\01.first\1685.png
# image file in writer() : 652 - img\01.first\1686.png
# image file in writer() : 653 - img\01.first\1687.png
# image file in writer() : 654 - img\01.first\1688.png
# image file in writer() : 655 - img\01.first\1689.png
# image file in writer() : 656 - img\01.first\169.png
# image file in writer() : 657 - img\01.first\1691.png
# image file in writer() : 658 - img\01.first\1692.png
# image file in writer() : 659 - img\01.first\1693.png
# image file in writer() : 660 - img\01.first\1694.png
# image file in writer() : 661 - img\01.first\1695.png
# image file in writer() : 662 - img\01.first\1697.png
# image file in writer() : 663 - img\01.first\1699.png
# image file in writer() : 664 - img\01.first\17.png
# image file in writer() : 665 - img\01.first\170.png
# image file in writer() : 666 - img\01.first\1700.png
# image file in writer() : 667 - img\01.first\1701.png
# image file in writer() : 668 - img\01.first\1702.png
# image file in writer() : 669 - img\01.first\1703.png
# image file in writer() : 670 - img\01.first\1704.png
# image file in writer() : 671 - img\01.first\1705.png
# image file in writer() : 672 - img\01.first\1706.png
# image file in writer() : 673 - img\01.first\1707.png
# image file in writer() : 674 - img\01.first\1708.png
# image file in writer() : 675 - img\01.first\1709.png
# image file in writer() : 676 - img\01.first\171.png
# image file in writer() : 677 - img\01.first\1710.png
# image file in writer() : 678 - img\01.first\1711.png
# image file in writer() : 679 - img\01.first\1712.png
# image file in writer() : 680 - img\01.first\1716.png
# image file in writer() : 681 - img\01.first\1717.png
# image file in writer() : 682 - img\01.first\1718.png
# image file in writer() : 683 - img\01.first\1719.png
# image file in writer() : 684 - img\01.first\172.png
# image file in writer() : 685 - img\01.first\1720.png
# image file in writer() : 686 - img\01.first\1721.png
# image file in writer() : 687 - img\01.first\1722.png
# image file in writer() : 688 - img\01.first\1723.png
# image file in writer() : 689 - img\01.first\1726.png
# image file in writer() : 690 - img\01.first\1727.png
# image file in writer() : 691 - img\01.first\1728.png
# image file in writer() : 692 - img\01.first\1729.png
# image file in writer() : 693 - img\01.first\173.png
# image file in writer() : 694 - img\01.first\1730.png
# image file in writer() : 695 - img\01.first\1731.png
# image file in writer() : 696 - img\01.first\1732.png
# image file in writer() : 697 - img\01.first\1735.png
# image file in writer() : 698 - img\01.first\1736.png
# image file in writer() : 699 - img\01.first\1737.png
# image file in writer() : 700 - img\01.first\1738.png
# image file in writer() : 701 - img\01.first\1739.png
# image file in writer() : 702 - img\01.first\174.png
# image file in writer() : 703 - img\01.first\1740.png
# image file in writer() : 704 - img\01.first\1741.png
# image file in writer() : 705 - img\01.first\1745.png
# image file in writer() : 706 - img\01.first\1746.png
# image file in writer() : 707 - img\01.first\1747.png
# image file in writer() : 708 - img\01.first\1748.png
# image file in writer() : 709 - img\01.first\1749.png
# image file in writer() : 710 - img\01.first\175.png
# image file in writer() : 711 - img\01.first\1750.png
# image file in writer() : 712 - img\01.first\1751.png
# image file in writer() : 713 - img\01.first\1755.png
# image file in writer() : 714 - img\01.first\1756.png
# image file in writer() : 715 - img\01.first\1757.png
# image file in writer() : 716 - img\01.first\1758.png
# image file in writer() : 717 - img\01.first\1759.png
# image file in writer() : 718 - img\01.first\176.png
# image file in writer() : 719 - img\01.first\1760.png
# image file in writer() : 720 - img\01.first\1761.png
# image file in writer() : 721 - img\01.first\1765.png
# image file in writer() : 722 - img\01.first\1766.png
# image file in writer() : 723 - img\01.first\1767.png
# image file in writer() : 724 - img\01.first\1768.png
# image file in writer() : 725 - img\01.first\1769.png
# image file in writer() : 726 - img\01.first\177.png
# image file in writer() : 727 - img\01.first\1770.png
# image file in writer() : 728 - img\01.first\1771.png
# image file in writer() : 729 - img\01.first\1773.png
# image file in writer() : 730 - img\01.first\1774.png
# image file in writer() : 731 - img\01.first\1775.png
# image file in writer() : 732 - img\01.first\1776.png
# image file in writer() : 733 - img\01.first\1777.png
# image file in writer() : 734 - img\01.first\1778.png
# image file in writer() : 735 - img\01.first\1779.png
# image file in writer() : 736 - img\01.first\178.png
# image file in writer() : 737 - img\01.first\1780.png
# image file in writer() : 738 - img\01.first\1783.png
# image file in writer() : 739 - img\01.first\1784.png
# image file in writer() : 740 - img\01.first\1785.png
# image file in writer() : 741 - img\01.first\1786.png
# image file in writer() : 742 - img\01.first\1787.png
# image file in writer() : 743 - img\01.first\1788.png
# image file in writer() : 744 - img\01.first\1789.png
# image file in writer() : 745 - img\01.first\179.png
# image file in writer() : 746 - img\01.first\1790.png
# image file in writer() : 747 - img\01.first\1791.png
# image file in writer() : 748 - img\01.first\1792.png
# image file in writer() : 749 - img\01.first\1793.png
# image file in writer() : 750 - img\01.first\1794.png
# image file in writer() : 751 - img\01.first\1795.png
# image file in writer() : 752 - img\01.first\1796.png
# image file in writer() : 753 - img\01.first\1797.png
# image file in writer() : 754 - img\01.first\1798.png
# image file in writer() : 755 - img\01.first\18.png
# image file in writer() : 756 - img\01.first\180.png
# image file in writer() : 757 - img\01.first\1800.png
# image file in writer() : 758 - img\01.first\1801.png
# image file in writer() : 759 - img\01.first\1802.png
# image file in writer() : 760 - img\01.first\1803.png
# image file in writer() : 761 - img\01.first\1805.png
# image file in writer() : 762 - img\01.first\1806.png
# image file in writer() : 763 - img\01.first\1807.png
# image file in writer() : 764 - img\01.first\181.png
# image file in writer() : 765 - img\01.first\1811.png
# image file in writer() : 766 - img\01.first\1812.png
# image file in writer() : 767 - img\01.first\1818.png
# image file in writer() : 768 - img\01.first\1819.png
# image file in writer() : 769 - img\01.first\182.png
# image file in writer() : 770 - img\01.first\1820.png
# image file in writer() : 771 - img\01.first\1821.png
# image file in writer() : 772 - img\01.first\1822.png
# image file in writer() : 773 - img\01.first\1823.png
# image file in writer() : 774 - img\01.first\1825.png
# image file in writer() : 775 - img\01.first\1826.png
# image file in writer() : 776 - img\01.first\1827.png
# image file in writer() : 777 - img\01.first\1828.png
# image file in writer() : 778 - img\01.first\1829.png
# image file in writer() : 779 - img\01.first\183.png
# image file in writer() : 780 - img\01.first\1830.png
# image file in writer() : 781 - img\01.first\1832.png
# image file in writer() : 782 - img\01.first\1833.png
# image file in writer() : 783 - img\01.first\1834.png
# image file in writer() : 784 - img\01.first\1835.png
# image file in writer() : 785 - img\01.first\1836.png
# image file in writer() : 786 - img\01.first\1837.png
# image file in writer() : 787 - img\01.first\1838.png
# image file in writer() : 788 - img\01.first\1839.png
# image file in writer() : 789 - img\01.first\184.png
# image file in writer() : 790 - img\01.first\1840.png
# image file in writer() : 791 - img\01.first\1841.png
# image file in writer() : 792 - img\01.first\1842.png
# image file in writer() : 793 - img\01.first\1843.png
# image file in writer() : 794 - img\01.first\1844.png
# image file in writer() : 795 - img\01.first\1846.png
# image file in writer() : 796 - img\01.first\1847.png
# image file in writer() : 797 - img\01.first\1848.png
# image file in writer() : 798 - img\01.first\1849.png
# image file in writer() : 799 - img\01.first\185.png
# image file in writer() : 800 - img\01.first\1850.png
# image file in writer() : 801 - img\01.first\1851.png
# image file in writer() : 802 - img\01.first\1852.png
# image file in writer() : 803 - img\01.first\1853.png
# image file in writer() : 804 - img\01.first\1854.png
# image file in writer() : 805 - img\01.first\1855.png
# image file in writer() : 806 - img\01.first\1856.png
# image file in writer() : 807 - img\01.first\1857.png
# image file in writer() : 808 - img\01.first\1858.png
# image file in writer() : 809 - img\01.first\1859.png
# image file in writer() : 810 - img\01.first\186.png
# image file in writer() : 811 - img\01.first\1860.png
# image file in writer() : 812 - img\01.first\1862.png
# image file in writer() : 813 - img\01.first\1864.png
# image file in writer() : 814 - img\01.first\1865.png
# image file in writer() : 815 - img\01.first\1866.png
# image file in writer() : 816 - img\01.first\1867.png
# image file in writer() : 817 - img\01.first\1868.png
# image file in writer() : 818 - img\01.first\1869.png
# image file in writer() : 819 - img\01.first\187.png
# image file in writer() : 820 - img\01.first\1870.png
# image file in writer() : 821 - img\01.first\1871.png
# image file in writer() : 822 - img\01.first\1872.png
# image file in writer() : 823 - img\01.first\1873.png
# image file in writer() : 824 - img\01.first\1874.png
# image file in writer() : 825 - img\01.first\1875.png
# image file in writer() : 826 - img\01.first\1876.png
# image file in writer() : 827 - img\01.first\1877.png
# image file in writer() : 828 - img\01.first\1878.png
# image file in writer() : 829 - img\01.first\1879.png
# image file in writer() : 830 - img\01.first\188.png
# image file in writer() : 831 - img\01.first\1880.png
# image file in writer() : 832 - img\01.first\1881.png
# image file in writer() : 833 - img\01.first\1882.png
# image file in writer() : 834 - img\01.first\1883.png
# image file in writer() : 835 - img\01.first\1884.png
# image file in writer() : 836 - img\01.first\1885.png
# image file in writer() : 837 - img\01.first\1886.png
# image file in writer() : 838 - img\01.first\1887.png
# image file in writer() : 839 - img\01.first\1888.png
# image file in writer() : 840 - img\01.first\1889.png
# image file in writer() : 841 - img\01.first\189.png
# image file in writer() : 842 - img\01.first\1890.png
# image file in writer() : 843 - img\01.first\1891.png
# image file in writer() : 844 - img\01.first\1892.png
# image file in writer() : 845 - img\01.first\1893.png
# image file in writer() : 846 - img\01.first\1894.png
# image file in writer() : 847 - img\01.first\1895.png
# image file in writer() : 848 - img\01.first\1896.png
# image file in writer() : 849 - img\01.first\1897.png
# image file in writer() : 850 - img\01.first\1898.png
# image file in writer() : 851 - img\01.first\1899.png
# image file in writer() : 852 - img\01.first\19.png
# image file in writer() : 853 - img\01.first\190.png
# image file in writer() : 854 - img\01.first\1900.png
# image file in writer() : 855 - img\01.first\1901.png
# image file in writer() : 856 - img\01.first\1902.png
# image file in writer() : 857 - img\01.first\1903.png
# image file in writer() : 858 - img\01.first\1904.png
# image file in writer() : 859 - img\01.first\1905.png
# image file in writer() : 860 - img\01.first\1906.png
# image file in writer() : 861 - img\01.first\1907.png
# image file in writer() : 862 - img\01.first\1908.png
# image file in writer() : 863 - img\01.first\1909.png
# image file in writer() : 864 - img\01.first\191.png
# image file in writer() : 865 - img\01.first\1910.png
# image file in writer() : 866 - img\01.first\1911.png
# image file in writer() : 867 - img\01.first\1913.png
# image file in writer() : 868 - img\01.first\1915.png
# image file in writer() : 869 - img\01.first\1916.png
# image file in writer() : 870 - img\01.first\1917.png
# image file in writer() : 871 - img\01.first\1918.png
# image file in writer() : 872 - img\01.first\1919.png
# image file in writer() : 873 - img\01.first\192.png
# image file in writer() : 874 - img\01.first\1920.png
# image file in writer() : 875 - img\01.first\1921.png
# image file in writer() : 876 - img\01.first\1922.png
# image file in writer() : 877 - img\01.first\1923.png
# image file in writer() : 878 - img\01.first\1924.png
# image file in writer() : 879 - img\01.first\1925.png
# image file in writer() : 880 - img\01.first\1926.png
# image file in writer() : 881 - img\01.first\1927.png
# image file in writer() : 882 - img\01.first\1928.png
# image file in writer() : 883 - img\01.first\1929.png
# image file in writer() : 884 - img\01.first\193.png
# image file in writer() : 885 - img\01.first\1930.png
# image file in writer() : 886 - img\01.first\1931.png
# image file in writer() : 887 - img\01.first\1932.png
# image file in writer() : 888 - img\01.first\1933.png
# image file in writer() : 889 - img\01.first\1934.png
# image file in writer() : 890 - img\01.first\1935.png
# image file in writer() : 891 - img\01.first\1936.png
# image file in writer() : 892 - img\01.first\1937.png
# image file in writer() : 893 - img\01.first\1938.png
# image file in writer() : 894 - img\01.first\1939.png
# image file in writer() : 895 - img\01.first\194.png
# image file in writer() : 896 - img\01.first\1940.png
# image file in writer() : 897 - img\01.first\1941.png
# image file in writer() : 898 - img\01.first\1942.png
# image file in writer() : 899 - img\01.first\1943.png
# image file in writer() : 900 - img\01.first\1944.png
# image file in writer() : 901 - img\01.first\1945.png
# image file in writer() : 902 - img\01.first\1946.png
# image file in writer() : 903 - img\01.first\1947.png
# image file in writer() : 904 - img\01.first\1948.png
# image file in writer() : 905 - img\01.first\1949.png
# image file in writer() : 906 - img\01.first\195.png
# image file in writer() : 907 - img\01.first\1950.png
# image file in writer() : 908 - img\01.first\1951.png
# image file in writer() : 909 - img\01.first\1952.png
# ...
# image file in writer() : 1565 - img\01.first\717.png
# image file in writer() : 1566 - img\01.first\718.png
# image file in writer() : 1567 - img\01.first\719.png
# image file in writer() : 1568 - img\01.first\72.png
# image file in writer() : 1569 - img\01.first\720.png
# image file in writer() : 1570 - img\01.first\721.png
# image file in writer() : 1571 - img\01.first\722.png
# image file in writer() : 1572 - img\01.first\723.png
# image file in writer() : 1573 - img\01.first\724.png
# image file in writer() : 1574 - img\01.first\725.png
# image file in writer() : 1575 - img\01.first\726.png
# image file in writer() : 1576 - img\01.first\727.png
# image file in writer() : 1577 - img\01.first\728.png
# image file in writer() : 1578 - img\01.first\729.png
# image file in writer() : 1579 - img\01.first\73.png
# image file in writer() : 1580 - img\01.first\730.png
# image file in writer() : 1581 - img\01.first\731.png
# image file in writer() : 1582 - img\01.first\732.png
# image file in writer() : 1583 - img\01.first\733.png
# image file in writer() : 1584 - img\01.first\734.png
# image file in writer() : 1585 - img\01.first\735.png
# image file in writer() : 1586 - img\01.first\736.png
# image file in writer() : 1587 - img\01.first\737.png
# image file in writer() : 1588 - img\01.first\738.png
# image file in writer() : 1589 - img\01.first\739.png
# image file in writer() : 1590 - img\01.first\74.png
# image file in writer() : 1591 - img\01.first\740.png
# image file in writer() : 1592 - img\01.first\741.png
# image file in writer() : 1593 - img\01.first\742.png
# image file in writer() : 1594 - img\01.first\743.png
# image file in writer() : 1595 - img\01.first\744.png
# image file in writer() : 1596 - img\01.first\745.png
# image file in writer() : 1597 - img\01.first\746.png
# image file in writer() : 1598 - img\01.first\747.png
# image file in writer() : 1599 - img\01.first\748.png
# image file in writer() : 1600 - img\01.first\749.png
# image file in writer() : 1601 - img\01.first\75.png
# image file in writer() : 1602 - img\01.first\750.png
# image file in writer() : 1603 - img\01.first\751.png
# image file in writer() : 1604 - img\01.first\752.png
# image file in writer() : 1605 - img\01.first\753.png
# image file in writer() : 1606 - img\01.first\754.png
# image file in writer() : 1607 - img\01.first\755.png
# image file in writer() : 1608 - img\01.first\756.png
# image file in writer() : 1609 - img\01.first\757.png
# image file in writer() : 1610 - img\01.first\758.png
# image file in writer() : 1611 - img\01.first\759.png
# image file in writer() : 1612 - img\01.first\76.png
# image file in writer() : 1613 - img\01.first\760.png
# image file in writer() : 1614 - img\01.first\761.png
# image file in writer() : 1615 - img\01.first\762.png
# image file in writer() : 1616 - img\01.first\763.png
# image file in writer() : 1617 - img\01.first\765.png
# image file in writer() : 1618 - img\01.first\766.png
# image file in writer() : 1619 - img\01.first\767.png
# image file in writer() : 1620 - img\01.first\768.png
# image file in writer() : 1621 - img\01.first\769.png
# image file in writer() : 1622 - img\01.first\77.png
# image file in writer() : 1623 - img\01.first\770.png
# image file in writer() : 1624 - img\01.first\771.png
# image file in writer() : 1625 - img\01.first\772.png
# image file in writer() : 1626 - img\01.first\773.png
# image file in writer() : 1627 - img\01.first\774.png
# image file in writer() : 1628 - img\01.first\775.png
# image file in writer() : 1629 - img\01.first\776.png
# image file in writer() : 1630 - img\01.first\777.png
# image file in writer() : 1631 - img\01.first\778.png
# image file in writer() : 1632 - img\01.first\779.png
# image file in writer() : 1633 - img\01.first\78.png
# image file in writer() : 1634 - img\01.first\780.png
# image file in writer() : 1635 - img\01.first\781.png
# image file in writer() : 1636 - img\01.first\782.png
# image file in writer() : 1637 - img\01.first\783.png
# image file in writer() : 1638 - img\01.first\784.png
# image file in writer() : 1639 - img\01.first\785.png
# image file in writer() : 1640 - img\01.first\786.png
# image file in writer() : 1641 - img\01.first\787.png
# image file in writer() : 1642 - img\01.first\788.png
# image file in writer() : 1643 - img\01.first\789.png
# image file in writer() : 1644 - img\01.first\79.png
# image file in writer() : 1645 - img\01.first\790.png
# image file in writer() : 1646 - img\01.first\791.png
# image file in writer() : 1647 - img\01.first\792.png
# image file in writer() : 1648 - img\01.first\793.png
# image file in writer() : 1649 - img\01.first\794.png
# image file in writer() : 1650 - img\01.first\797.png
# image file in writer() : 1651 - img\01.first\798.png
# image file in writer() : 1652 - img\01.first\799.png
# image file in writer() : 1653 - img\01.first\8.png
# image file in writer() : 1654 - img\01.first\80.png
# image file in writer() : 1655 - img\01.first\800.png
# image file in writer() : 1656 - img\01.first\801.png
# image file in writer() : 1657 - img\01.first\802.png
# image file in writer() : 1658 - img\01.first\803.png
# image file in writer() : 1659 - img\01.first\804.png
# image file in writer() : 1660 - img\01.first\805.png
# image file in writer() : 1661 - img\01.first\806.png
# image file in writer() : 1662 - img\01.first\807.png
# image file in writer() : 1663 - img\01.first\808.png
# image file in writer() : 1664 - img\01.first\809.png
# image file in writer() : 1665 - img\01.first\81.png
# image file in writer() : 1666 - img\01.first\810.png
# image file in writer() : 1667 - img\01.first\811.png
# image file in writer() : 1668 - img\01.first\812.png
# image file in writer() : 1669 - img\01.first\813.png
# image file in writer() : 1670 - img\01.first\814.png
# image file in writer() : 1671 - img\01.first\815.png
# image file in writer() : 1672 - img\01.first\816.png
# image file in writer() : 1673 - img\01.first\817.png
# image file in writer() : 1674 - img\01.first\818.png
# image file in writer() : 1675 - img\01.first\819.png
# image file in writer() : 1676 - img\01.first\82.png
# image file in writer() : 1677 - img\01.first\820.png
# image file in writer() : 1678 - img\01.first\821.png
# image file in writer() : 1679 - img\01.first\822.png
# image file in writer() : 1680 - img\01.first\823.png
# image file in writer() : 1681 - img\01.first\824.png
# image file in writer() : 1682 - img\01.first\825.png
# image file in writer() : 1683 - img\01.first\826.png
# image file in writer() : 1684 - img\01.first\827.png
# image file in writer() : 1685 - img\01.first\828.png
# image file in writer() : 1686 - img\01.first\829.png
# image file in writer() : 1687 - img\01.first\83.png
# image file in writer() : 1688 - img\01.first\830.png
# image file in writer() : 1689 - img\01.first\831.png
# image file in writer() : 1690 - img\01.first\832.png
# image file in writer() : 1691 - img\01.first\833.png
# image file in writer() : 1692 - img\01.first\834.png
# image file in writer() : 1693 - img\01.first\835.png
# image file in writer() : 1694 - img\01.first\836.png
# image file in writer() : 1695 - img\01.first\837.png
# image file in writer() : 1696 - img\01.first\838.png
# image file in writer() : 1697 - img\01.first\839.png
# image file in writer() : 1698 - img\01.first\84.png
# image file in writer() : 1699 - img\01.first\840.png
# image file in writer() : 1700 - img\01.first\841.png
# image file in writer() : 1701 - img\01.first\842.png
# image file in writer() : 1702 - img\01.first\843.png
# image file in writer() : 1703 - img\01.first\844.png
# image file in writer() : 1704 - img\01.first\845.png
# image file in writer() : 1705 - img\01.first\846.png
# image file in writer() : 1706 - img\01.first\847.png
# image file in writer() : 1707 - img\01.first\848.png
# image file in writer() : 1708 - img\01.first\849.png
# image file in writer() : 1709 - img\01.first\85.png
# image file in writer() : 1710 - img\01.first\850.png
# image file in writer() : 1711 - img\01.first\851.png
# image file in writer() : 1712 - img\01.first\854.png
# image file in writer() : 1713 - img\01.first\855.png
# image file in writer() : 1714 - img\01.first\856.png
# image file in writer() : 1715 - img\01.first\857.png
# image file in writer() : 1716 - img\01.first\858.png
# image file in writer() : 1717 - img\01.first\859.png
# image file in writer() : 1718 - img\01.first\86.png
# image file in writer() : 1719 - img\01.first\860.png
# image file in writer() : 1720 - img\01.first\861.png
# image file in writer() : 1721 - img\01.first\862.png
# image file in writer() : 1722 - img\01.first\863.png
# image file in writer() : 1723 - img\01.first\864.png
# image file in writer() : 1724 - img\01.first\865.png
# image file in writer() : 1725 - img\01.first\866.png
# image file in writer() : 1726 - img\01.first\867.png
# image file in writer() : 1727 - img\01.first\868.png
# image file in writer() : 1728 - img\01.first\869.png
# image file in writer() : 1729 - img\01.first\87.png
# image file in writer() : 1730 - img\01.first\870.png
# image file in writer() : 1731 - img\01.first\871.png
# image file in writer() : 1732 - img\01.first\872.png
# image file in writer() : 1733 - img\01.first\873.png
# image file in writer() : 1734 - img\01.first\874.png
# image file in writer() : 1735 - img\01.first\875.png
# image file in writer() : 1736 - img\01.first\876.png
# image file in writer() : 1737 - img\01.first\877.png
# image file in writer() : 1738 - img\01.first\878.png
# image file in writer() : 1739 - img\01.first\879.png
# image file in writer() : 1740 - img\01.first\88.png
# image file in writer() : 1741 - img\01.first\880.png
# image file in writer() : 1742 - img\01.first\881.png
# image file in writer() : 1743 - img\01.first\882.png
# image file in writer() : 1744 - img\01.first\883.png
# image file in writer() : 1745 - img\01.first\884.png
# image file in writer() : 1746 - img\01.first\885.png
# image file in writer() : 1747 - img\01.first\886.png
# image file in writer() : 1748 - img\01.first\887.png
# image file in writer() : 1749 - img\01.first\888.png
# image file in writer() : 1750 - img\01.first\889.png
# image file in writer() : 1751 - img\01.first\89.png
# image file in writer() : 1752 - img\01.first\890.png
# image file in writer() : 1753 - img\01.first\891.png
# image file in writer() : 1754 - img\01.first\892.png
# image file in writer() : 1755 - img\01.first\893.png
# image file in writer() : 1756 - img\01.first\895.png
# image file in writer() : 1757 - img\01.first\896.png
# image file in writer() : 1758 - img\01.first\897.png
# image file in writer() : 1759 - img\01.first\898.png
# image file in writer() : 1760 - img\01.first\899.png
# image file in writer() : 1761 - img\01.first\9.png
# image file in writer() : 1762 - img\01.first\90.png
# image file in writer() : 1763 - img\01.first\900.png
# image file in writer() : 1764 - img\01.first\901.png
# image file in writer() : 1765 - img\01.first\902.png
# image file in writer() : 1766 - img\01.first\903.png
# image file in writer() : 1767 - img\01.first\904.png
# image file in writer() : 1768 - img\01.first\905.png
# image file in writer() : 1769 - img\01.first\906.png
# image file in writer() : 1770 - img\01.first\907.png
# image file in writer() : 1771 - img\01.first\908.png
# image file in writer() : 1772 - img\01.first\909.png
# image file in writer() : 1773 - img\01.first\91.png
# image file in writer() : 1774 - img\01.first\910.png
# image file in writer() : 1775 - img\01.first\911.png
# image file in writer() : 1776 - img\01.first\912.png
# image file in writer() : 1777 - img\01.first\913.png
# image file in writer() : 1778 - img\01.first\914.png
# image file in writer() : 1779 - img\01.first\915.png
# image file in writer() : 1780 - img\01.first\916.png
# image file in writer() : 1781 - img\01.first\917.png
# image file in writer() : 1782 - img\01.first\918.png
# image file in writer() : 1783 - img\01.first\919.png
# image file in writer() : 1784 - img\01.first\92.png
# image file in writer() : 1785 - img\01.first\920.png
# image file in writer() : 1786 - img\01.first\921.png
# image file in writer() : 1787 - img\01.first\922.png
# image file in writer() : 1788 - img\01.first\923.png
# image file in writer() : 1789 - img\01.first\924.png
# image file in writer() : 1790 - img\01.first\925.png
# image file in writer() : 1791 - img\01.first\926.png
# image file in writer() : 1792 - img\01.first\927.png
# image file in writer() : 1793 - img\01.first\928.png
# image file in writer() : 1794 - img\01.first\929.png
# image file in writer() : 1795 - img\01.first\93.png
# image file in writer() : 1796 - img\01.first\930.png
# image file in writer() : 1797 - img\01.first\931.png
# image file in writer() : 1798 - img\01.first\932.png
# image file in writer() : 1799 - img\01.first\933.png
# image file in writer() : 1800 - img\01.first\934.png
# image file in writer() : 1801 - img\01.first\935.png
# image file in writer() : 1802 - img\01.first\936.png
# image file in writer() : 1803 - img\01.first\937.png
# image file in writer() : 1804 - img\01.first\938.png
# image file in writer() : 1805 - img\01.first\939.png
# image file in writer() : 1806 - img\01.first\94.png
# image file in writer() : 1807 - img\01.first\940.png
# image file in writer() : 1808 - img\01.first\941.png
# image file in writer() : 1809 - img\01.first\942.png
# image file in writer() : 1810 - img\01.first\943.png
# image file in writer() : 1811 - img\01.first\944.png
# image file in writer() : 1812 - img\01.first\945.png
# image file in writer() : 1813 - img\01.first\946.png
# image file in writer() : 1814 - img\01.first\947.png
# image file in writer() : 1815 - img\01.first\948.png
# image file in writer() : 1816 - img\01.first\949.png
# image file in writer() : 1817 - img\01.first\95.png
# image file in writer() : 1818 - img\01.first\950.png
# image file in writer() : 1819 - img\01.first\951.png
# image file in writer() : 1820 - img\01.first\952.png
# image file in writer() : 1821 - img\01.first\953.png
# image file in writer() : 1822 - img\01.first\954.png
# image file in writer() : 1823 - img\01.first\955.png
# image file in writer() : 1824 - img\01.first\956.png
# image file in writer() : 1825 - img\01.first\957.png
# image file in writer() : 1826 - img\01.first\958.png
# image file in writer() : 1827 - img\01.first\959.png
# image file in writer() : 1828 - img\01.first\96.png
# image file in writer() : 1829 - img\01.first\960.png
# image file in writer() : 1830 - img\01.first\961.png
# image file in writer() : 1831 - img\01.first\962.png
# image file in writer() : 1832 - img\01.first\963.png
# image file in writer() : 1833 - img\01.first\964.png
# image file in writer() : 1834 - img\01.first\965.png
# image file in writer() : 1835 - img\01.first\97.png
# image file in writer() : 1836 - img\01.first\972.png
# image file in writer() : 1837 - img\01.first\973.png
# image file in writer() : 1838 - img\01.first\974.png
# image file in writer() : 1839 - img\01.first\975.png
# image file in writer() : 1840 - img\01.first\976.png
# image file in writer() : 1841 - img\01.first\977.png
# image file in writer() : 1842 - img\01.first\978.png
# image file in writer() : 1843 - img\01.first\979.png
# image file in writer() : 1844 - img\01.first\98.png
# image file in writer() : 1845 - img\01.first\980.png
# image file in writer() : 1846 - img\01.first\981.png
# image file in writer() : 1847 - img\01.first\982.png
# image file in writer() : 1848 - img\01.first\983.png
# image file in writer() : 1849 - img\01.first\984.png
# image file in writer() : 1850 - img\01.first\985.png
# image file in writer() : 1851 - img\01.first\986.png
# image file in writer() : 1852 - img\01.first\987.png
# image file in writer() : 1853 - img\01.first\988.png
# image file in writer() : 1854 - img\01.first\989.png
# image file in writer() : 1855 - img\01.first\99.png
# image file in writer() : 1856 - img\01.first\990.png
# image file in writer() : 1857 - img\01.first\991.png
# image file in writer() : 1858 - img\01.first\992.png
# image file in writer() : 1859 - img\01.first\993.png
# image file in writer() : 1860 - img\01.first\994.png
# image file in writer() : 1861 - img\01.first\995.png
# image file in writer() : 1862 - img\01.first\996.png
# image file in writer() : 1863 - img\01.first\997.png
# image file in writer() : 1864 - img\01.first\998.png
# image file in writer() : 1865 - img\01.first\999.png
# Start at 20231006-100833
# time : 763.1893255710602
# Finished
